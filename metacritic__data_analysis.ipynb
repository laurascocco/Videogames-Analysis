# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## EDA

# %%
df_vg = pd.read_csv("\\Users\\laura\\Desktop\\Progetto finale\\Videogames\\metacritic_final.csv")

# %%
df_vg
# Out:
#                                        Game_name      Game_platform  \
# 0                                         "Hook"  iOS (iPhone/iPad)
# 1                                          #Blud                 PC
# 2                                         #Drive  iOS (iPhone/iPad)
# 3                                   #Drive Rally      Xbox Series X
# 4                                         #Idarb           Xbox One
# ...                                          ...                ...
# 14622  Thinksmart: Scotland Yard - Hunting Mr. X                 DS
# 14623                               Udraw Studio                Wii
# 14624             Void Trrlm(); //Void Terrarium    Nintendo Switch
# 14625                              Wipeout Merge  iOS (iPhone/iPad)
# 14626                                        Xxx   Game Boy Advance
#
#       Game_release_date           Game_developer        Game_distribution  \
# 0            2015-01-20            Megabyte Bomb            Megabyte Bomb
# ...

# %%
no_date = df_vg[df_vg['Game_release_date'].isna()]
no_date
# Out:
#                        Game_name      Game_platform Game_release_date  \
# 3                   #Drive Rally      Xbox Series X               NaN
# 55               2 Days To Vegas                 PC               NaN
# 66                          2Xko                 PC               NaN
# 70        3-D Dinosaur Adventure                 PC               NaN
# 72                       3-Demon                 PC               NaN
# ...                          ...                ...               ...
# 14434       Youkoso Iruka Park E                 DS               NaN
# 14554                 Zooloretto                Wii               NaN
# 14556               Zork Trilogy                 PC               NaN
# 14598  Fault: Silence The Pedant                 PC               NaN
# 14625              Wipeout Merge  iOS (iPhone/iPad)               NaN
#
#               Game_developer    Game_distribution        Game_genre  \
# ...

# %%
df_vg.size
# Out:
# 160897

# %%
df_vg.shape
# Out:
# (14627, 11)

# %%
df_vg.columns
# Out:
# Index(['Game_name', 'Game_platform', 'Game_release_date', 'Game_developer',
#        'Game_distribution', 'Game_genre', 'Critic_score_0_100',
#        'Critic_num_reviews', 'User_score_0_10', 'User_num_reviews', 'Link'],
#       dtype='object')

# %%
df_vg.head(5)
# Out:
#       Game_name      Game_platform Game_release_date           Game_developer  \
# 0        "Hook"  iOS (iPhone/iPad)        2015-01-20            Megabyte Bomb
# 1         #Blud                 PC        2024-06-18          Exit 73 Studios
# 2        #Drive  iOS (iPhone/iPad)        2021-02-16         Dariusz Pietrala
# 3  #Drive Rally      Xbox Series X               NaN       Pixel Perfect Dude
# 4        #Idarb           Xbox One        2015-01-30  Other Ocean Interactive
#
#          Game_distribution        Game_genre  Critic_score_0_100  \
# 0            Megabyte Bomb            Puzzle                 NaN
# 1             Humble Games  Action Adventure                 NaN
# 2          PM Studios Inc.       Auto Racing                69.0
# 3       Pixel Perfect Dude     Arcade Racing                 NaN
# 4  Other Ocean Interactive             Party                77.0
#
#    Critic_num_reviews  User_score_0_10  User_num_reviews  \
# ...

# %%
df_vg.sample(10)
# Out:
#                              Game_name     Game_platform Game_release_date  \
# 9996   Rugrats: Adventures In Gameland     PlayStation 5        2024-08-16
# 10991              Southern Princesses                PC        2022-08-08
# 2133    Code Lyoko: Quest For Infinity               Wii        2007-11-16
# 6661        Lords Of The Fallen (2014)     PlayStation 4        2014-10-28
# 4341     Fire Emblem Fates: Birthright               3DS        2016-02-19
# 9855              Road Rash: Jailbreak       PlayStation        2003-09-11
# 6087                            Kamiko   Nintendo Switch        2017-04-27
# 12546                        The Mummy  Game Boy Advance        2000-11-17
# 10576      Shinobido 2: Revenge Of Zen  PlayStation Vita        2012-02-21
# 11866  Tales From Off-Peak City Vol. 1                PC        2020-05-15
#
#             Game_developer   Game_distribution              Game_genre  \
# ...

# %%
df_vg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14627 entries, 0 to 14626
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Game_name           14627 non-null  object
#  1   Game_platform       14627 non-null  object
#  2   Game_release_date   14245 non-null  object
#  3   Game_developer      14536 non-null  object
#  4   Game_distribution   14536 non-null  object
#  5   Game_genre          14627 non-null  object
#  6   Critic_score_0_100  13483 non-null  float64
#  7   Critic_num_reviews  13488 non-null  float64
#  8   User_score_0_10     11545 non-null  float64
#  9   User_num_reviews    11150 non-null  float64
#  10  Link                14627 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.2+ MB

# %%
df_vg.describe()
# Out:
#        Critic_score_0_100  Critic_num_reviews  User_score_0_10  \
# count        13483.000000        13488.000000     11545.000000
# mean            69.226760           25.937203         6.910411
# std             14.642805           20.756637         1.393852
# min              0.300000            4.000000         0.300000
# 25%             63.000000           11.000000         6.200000
# 50%             72.000000           19.000000         7.200000
# 75%             79.000000           34.000000         7.900000
# max             99.000000          176.000000        10.000000
#
#        User_num_reviews
# count      11150.000000
# mean         253.826457
# std         1871.283249
# min            4.000000
# 25%           14.000000
# 50%           35.000000
# 75%          115.000000
# max       163766.000000

# %%
df_vg["Game_platform"].value_counts()
# Out:
# Game_platform
# PC                   5507
# PlayStation 4        1035
# PlayStation 2         970
# Xbox 360              912
# Nintendo Switch       832
# PlayStation 3         794
# DS                    615
# Wii                   462
# Xbox One              424
# Game Boy Advance      369
# PSP                   368
# 3DS                   356
# Xbox                  340
# iOS (iPhone/iPad)     334
# PlayStation Vita      245
# PlayStation 5         240
# PlayStation           192
# GameCube              190
# Wii U                 130
# Xbox Series X         126
# Dreamcast             110
# Nintendo 64            68
# Meta Quest              8
# Name: count, dtype: int64

# %%
colors = plt.cm.viridis(np.linspace(0, 1, len(df_vg["Game_platform"].value_counts())))

plt.figure(figsize=(10, 6))
df_vg["Game_platform"].value_counts().plot(kind='bar', color=colors)
plt.title('Game Platform Counts', fontsize=20)
plt.xlabel('Platform')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
df_vg["Game_developer"].value_counts()
# Out:
# Game_developer
# Capcom                  177
# Nintendo                153
# Telltale Games          115
# Konami                  108
# Ubisoft                  81
#                        ...
# Rewolf Software           1
# Claeys Brothers Arts      1
# Crazy Monkey Studios      1
# Daybreak Games            1
# Amuzo Games Ltd           1
# Name: count, Length: 4815, dtype: int64

# %%
colors = plt.cm.viridis(np.linspace(0, 1, 20))  

plt.figure(figsize=(10, 6))
df_vg["Game_developer"].value_counts().head(20).plot(kind='bar', color=colors)
plt.title('Top 20 Game Developers by Count', fontsize=20)
plt.xlabel('Developer')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
df_vg["Game_distribution"].value_counts()
# Out:
# Game_distribution
# Nintendo               621
# Ubisoft                450
# SCEA                   410
# Sega                   408
# Electronic Arts        370
#                       ...
# Intelligent Design       1
# Defiant Development      1
# HFM Games                1
# Jens Kolhammar           1
# Mentor Interactive       1
# Name: count, Length: 2515, dtype: int64

# %%
colors = plt.cm.viridis(np.linspace(0, 1, 20))  

plt.figure(figsize=(10, 6))
df_vg["Game_distribution"].value_counts().head(20).plot(kind='bar', color=colors)
plt.title('Top 20 Game Distribution by Count', fontsize=20)
plt.xlabel('Distribution')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
df_vg["Game_genre"].value_counts()
# Out:
# Game_genre
# Action Adventure      773
# 2D Platformer         771
# Action RPG            666
# FPS                   613
# Real-Time Strategy    401
#                      ...
# Bowling                 6
# Team Sports             5
# Cricket                 5
# Marine Sim              4
# Racing Sim              1
# Name: count, Length: 119, dtype: int64

# %%
colors = plt.cm.viridis(np.linspace(0, 1, 20))  

plt.figure(figsize=(10, 6))
df_vg["Game_genre"].value_counts().head(20).plot(kind='bar', color=colors)
plt.title('Top 20 Game Genre by Count', fontsize=20)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right',fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
df_vg["Game_release_date"].value_counts()
# Out:
# Game_release_date
# 2006-11-14    29
# 2012-11-18    22
# 2003-11-18    22
# 2007-03-20    21
# 2007-10-23    21
#               ..
# 2008-12-29     1
# 2001-07-03     1
# 2007-07-05     1
# 2000-09-13     1
# 2010-12-13     1
# Name: count, Length: 4935, dtype: int64

# %%
total_reviews_critic_distribution = (df_vg.groupby("Game_distribution")["Critic_num_reviews"]
                                      .sum()
                                      .reset_index(name="reviews_distribution")
                                      .sort_values(by="reviews_distribution", ascending=False))

# %%
total_reviews_critic_distribution
# Out:
#            Game_distribution  reviews_distribution
# 1488                Nintendo               27807.0
# 1843                    SCEA               15963.0
# 2252                 Ubisoft               13810.0
# 1893                    Sega               13419.0
# 1354  Microsoft Game Studios               12407.0
# ...                      ...                   ...
# 1119             IshiEiketsu                   0.0
# 2249               USC Games                   0.0
# 1112                    Irem                   0.0
# 2247                 UP7.DEV                   0.0
# 2514                  yuwaka                   0.0
#
# [2515 rows x 2 columns]

# %%
top_20_reviews = total_reviews_critic_distribution.head(20)

colors = plt.cm.viridis(np.linspace(0, 1, len(top_20_reviews)))

plt.figure(figsize=(10, 6))
plt.bar(top_20_reviews["Game_distribution"], 
        top_20_reviews["reviews_distribution"], 
        color=colors)
plt.title('Top 20 Total Critic Reviews by Distribution', fontsize=16)
plt.xlabel('Game Distribution', fontsize=14)
plt.ylabel('Total Critic Reviews', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
total_reviews_user_distribution = (df_vg.groupby("Game_distribution")["User_num_reviews"]
                                      .sum()
                                      .reset_index(name="reviews_distribution")
                                      .sort_values(by="reviews_distribution", ascending=False))

# %%
total_reviews_user_distribution
# Out:
#                    Game_distribution  reviews_distribution
# 1980  Sony Interactive Entertainment              350822.0
# 1488                        Nintendo              271360.0
# 1843                            SCEA              166024.0
# 678                  Electronic Arts              140505.0
# 2013                     Square Enix              116971.0
# ...                              ...                   ...
# 262                  Big Stupid Face                   0.0
# 1311                Maschinen-Mensch                   0.0
# 530              Dagestan Technology                   0.0
# 1992                      Space Mace                   0.0
# 2514                          yuwaka                   0.0
#
# [2515 rows x 2 columns]

# %%
top_20_reviews = total_reviews_user_distribution.head(20)

colors = plt.cm.viridis(np.linspace(0, 1, len(top_20_reviews)))

plt.figure(figsize=(10, 6))
plt.bar(top_20_reviews["Game_distribution"], 
        top_20_reviews["reviews_distribution"], 
        color=colors)
plt.title('Top 20 Total User Reviews by Distribution', fontsize=16)
plt.xlabel('Game Distribution', fontsize=14)
plt.ylabel('Total User Reviews', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
reviews_by_platform_top20 = (df_vg.groupby('Game_platform')
                             .agg({'Critic_score_0_100': 'mean', 'User_score_0_10': lambda x: x.mean() * 10})
                             .head(20))

colors = ['purple', 'gold'] * (len(reviews_by_platform_top20) // 2)

plt.figure(figsize=(10, 6))
reviews_by_platform_top20[['Critic_score_0_100', 'User_score_0_10']].plot(kind='bar', color=colors, width=0.8)
plt.title('Top 20 Average Critic and User Scores by Platform', fontsize=16)
plt.xlabel('Platform', fontsize=14)
plt.ylabel('Average Score', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.legend(['Critic Score', 'User Score (x10)'], fontsize=12)
plt.tight_layout()
plt.show()

# %%
reviews_by_platform = df_vg.groupby('Game_platform').agg({'Critic_num_reviews': 'sum', 'User_num_reviews': 'sum'})

plt.figure(figsize=(10, 6))
reviews_by_platform.plot(kind='bar', color = ['purple', 'gold'], stacked=True)
plt.title('Number of Reviews by Platform')
plt.xlabel('Platform')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
top_20_reviews_by_genre = df_vg.groupby('Game_genre').agg({'Critic_num_reviews': 'sum', 'User_num_reviews': 'sum'}).sum(axis=1).nlargest(20)

colors = plt.cm.viridis(np.linspace(0, 1, len(top_20_reviews_by_genre)))

plt.figure(figsize=(10, 6))
plt.bar(top_20_reviews_by_genre.index, 
        top_20_reviews_by_genre.values, 
        color=colors)
plt.title('Top 20 Genres by Number of Reviews', fontsize=16, color='red', alpha=0.5)
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Total Reviews', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
df_vg['Release_Year'] = pd.to_datetime(df_vg['Game_release_date']).dt.year

reviews_by_year = df_vg.groupby('Release_Year').agg({'Critic_num_reviews': 'sum', 'User_num_reviews': 'sum'})

plt.figure(figsize=(12, 6))
plt.scatter(reviews_by_year.index, reviews_by_year.sum(axis=1), color='blue')
plt.title('Number of Reviews by Release Year', fontsize=16)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Total Reviews', fontsize=12)
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# What happend in 2020

# %%
reviews_2020 = df_vg[df_vg['Release_Year'] == 2020][['Game_name', 'Critic_num_reviews', 'User_num_reviews']]

reviews_2020[['Critic_num_reviews', 'User_num_reviews']] = reviews_2020[['Critic_num_reviews', 'User_num_reviews']].fillna(pd.NA).astype('Int64')

reviews_2020 = reviews_2020.sort_values(by=['User_num_reviews', 'Critic_num_reviews'], ascending=False)

reviews_2020
# Out:
#                       Game_name  Critic_num_reviews  User_num_reviews
# 12425    The Last Of Us Part Ii                 132            163766
# 2504             Cyberpunk 2077                 106             35494
# 13871    Warcraft Iii: Reforged                  53             31161
# 4840          Ghost Of Tsushima                 132             21974
# 4297   Final Fantasy Vii Remake                 135              8532
# ...                         ...                 ...               ...
# 11052           Sparkle 4 Tales                <NA>              <NA>
# 11363             Steam Tactics                <NA>              <NA>
# 11764     Swordbreaker The Game                <NA>              <NA>
# 11997              Tennis 1920S                <NA>              <NA>
# 12269       The Fairyland Story                <NA>              <NA>
#
# [651 rows x 3 columns]

# %%
top_10_reviews_2020 = reviews_2020.head(10)

colors = plt.cm.viridis(np.linspace(0, 1, len(top_10_reviews_2020)))

plt.figure(figsize=(10, 6))
plt.bar(top_10_reviews_2020["Game_name"], 
        top_10_reviews_2020["User_num_reviews"], 
        color=colors)
plt.title('Top 10 User Reviews for 2020', fontsize=16)
plt.xlabel('Game Name', fontsize=14)
plt.ylabel('Total User Reviews', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
total_reviews_2020 = int(reviews_2020[['Critic_num_reviews', 'User_num_reviews']].sum().sum())
total_reviews_2020
# Out:
# 397694

# %%
df_vg['Total_reviews'] = df_vg[['Critic_num_reviews', 'User_num_reviews']].fillna(0).sum(axis=1).astype(int)

top_10_games = df_vg.nlargest(10, 'Total_reviews')[['Game_name', 'Game_release_date', 'Critic_num_reviews', 'Critic_score_0_100', 'User_num_reviews', 'User_score_0_10', 'Total_reviews']]

top_10_games
# Out:
#                                      Game_name Game_release_date  \
# 12425                   The Last Of Us Part Ii        2020-06-19
# 2504                            Cyberpunk 2077        2020-12-10
# 13871                   Warcraft Iii: Reforged        2020-01-28
# 4920                                God Of War        2018-04-20
# 9602                     Red Dead Redemption 2        2018-10-26
# 12461  The Legend Of Zelda: Breath Of The Wild        2017-03-03
# 4840                         Ghost Of Tsushima        2020-07-17
# 12427                The Last Of Us Remastered        2014-07-29
# 12852                 The Witcher 3: Wild Hunt        2015-05-19
# 2828                           Death Stranding        2019-11-08
#
#        Critic_num_reviews  Critic_score_0_100  User_num_reviews  \
# 12425               132.0                93.0          163766.0
# 2504                106.0                86.0           35494.0
# ...

# %%
top_10_games = df_vg.nlargest(10, 'Total_reviews')
colors = plt.cm.viridis(np.linspace(0, 1, len(top_10_games)))

plt.figure(figsize=(10, 6))
plt.bar(top_10_games["Game_name"], 
        top_10_games["Total_reviews"], 
        color=colors)
plt.title('Top 10 Games by Total Reviews', fontsize=16)
plt.xlabel('Game Name', fontsize=14)
plt.ylabel('Total Reviews', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_vg['Critic_score_0_100'].dropna(), bins=40, color='purple', alpha=0.7)
plt.xlabel('Critic Score (0-100)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Critic Review Scores', fontsize=16)
plt.grid(True)
plt.show()

# %%
user_score_scaled = df_vg['User_score_0_10'].dropna() * 10

plt.figure(figsize=(10, 6))
plt.hist(user_score_scaled, bins=40, color='darkolivegreen', alpha=0.7)
plt.xlabel('User Score (0-100)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of User Review Scores', fontsize=16)
plt.grid(True)
plt.show()

# %%
avg_critic_score = df_vg.groupby('Release_Year')['Critic_score_0_100'].mean()

avg_user_score = df_vg.groupby('Release_Year')['User_score_0_10'].mean() * 10

plt.figure(figsize=(12, 6))
plt.plot(avg_critic_score.index, avg_critic_score, marker='o', color='blue', label='Average Critic Score')
plt.plot(avg_user_score.index, avg_user_score, marker='o', color='green', label='Average User Score (x10)')
plt.title('Average Critic and User Scores by Release Year', fontsize=16)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Average Score', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
reviews_2024 = df_vg[df_vg['Release_Year'] == 2024][['Game_name', 'Critic_num_reviews', 'User_num_reviews', 'Critic_score_0_100', 'User_score_0_10']]
reviews_2024[['Critic_num_reviews', 'User_num_reviews']] = reviews_2024[['Critic_num_reviews', 'User_num_reviews']].fillna(pd.NA).astype('Int64')
reviews_2024 = reviews_2024.sort_values(by=['User_num_reviews', 'Critic_num_reviews', 'Critic_score_0_100', 'User_score_0_10'], ascending=False)
reviews_2024
# Out:
#                                     Game_name  Critic_num_reviews  \
# 11398                           Stellar Blade                 127
# 4296                Final Fantasy Vii Rebirth                 141
# 11539  Suicide Squad: Kill The Justice League                  90
# 5420                             Helldivers 2                  66
# 12426       The Last Of Us Part Ii Remastered                  91
# ...                                       ...                 ...
# 13419                Twizzle Puzzle: Reptiles                <NA>
# 13455                               Underdogs                <NA>
# 13494                               Umbraclaw                <NA>
# 13905       Warhammer 40,000: Space Marine Ii                <NA>
# 14149                              Witch Rise                <NA>
#
#        User_num_reviews  Critic_score_0_100  User_score_0_10
# 11398              4718                82.0              9.2
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_vg['Critic_num_reviews'], df_vg['Critic_score_0_100'], alpha=0.5)
plt.xlabel('Critic Number of Reviews')
plt.ylabel('Critic Score')
plt.title('Relationship between Total Critic Reviews and Critic Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_vg['User_num_reviews'], df_vg['User_score_0_10'] * 10, alpha=0.5)
plt.xlabel('User_num_reviews')
plt.ylabel('User Score (multiplied by 10)')
plt.title('Relationship between Total User Reviews and User Score')
plt.grid(True)
plt.show()

# %% [markdown]
# Analyze better the values between 0 and 20000 n° reviews

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_vg['User_num_reviews'], df_vg['User_score_0_10'] * 10, alpha=0.5)
plt.xlabel('User_num_reviews')
plt.ylabel('User Score (multiplied by 10)')
plt.title('Relationship between Total User Reviews and User Score')
plt.grid(True)

# Limit of 20000
plt.xlim(0, 20000)
plt.show()
