# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_vg = pd.read_csv("\\Users\\laura\\Desktop\\Progetto finale\\Videogames\\metacritic_data1.csv")

# %%
df_vg
# Out:
#                                   Game_name  Game_platform Game_release_date  \
# 0      The Legend of Zelda: Ocarina of Time    Nintendo 64        23/11/1998
# 1                               SoulCalibur      Dreamcast        08/09/1999
# 2                       Grand Theft Auto IV  PlayStation 3        29/04/2008
# 3                        Super Mario Galaxy            Wii        12/11/2007
# 4                      Super Mario Galaxy 2            Wii        23/05/2010
# ...                                     ...            ...               ...
# 13007                          KISS Pinball    PlayStation        25/04/2001
# 13008                       Survivor (2001)             PC        12/11/2001
# 13009                      Jenga World Tour             DS        07/12/2007
# 13010                           Pulse Racer           Xbox        02/01/2003
# 13011                              V Rising             PC        08/05/2024
#
# ...

# %%
no_date = df_vg[df_vg['Game_release_date'].isna()]
no_date
# Out:
#                                          Game_name      Game_platform  \
# 10966                    Football Manager Handheld           Xbox 360
# 10968                                    Soul Edge        PlayStation
# 10970  Age of Empires II: The Conquerors Expansion                 PC
# 10973                          Ultimate Card Games   Game Boy Advance
# 10975                Worldwide Soccer Manager 2007           Xbox 360
# 11008                          Myst IV: Revelation                 PC
# 11023                                       Wetrix                 PC
# 11057           The King of Fighters EX: Neo Blood   Game Boy Advance
# 11091                                     RayStorm        PlayStation
# 11216                            American Conquest                 PC
# 11262                  Battlefield 2: Armored Fury                 PC
# 11288                              A Vampyre Story                 PC
# ...

# %%
df_vg.size
# Out:
# 143132

# %%
df_vg.shape
# Out:
# (13012, 11)

# %%
df_vg.columns
# Out:
# Index(['Game_name', 'Game_platform', 'Game_release_date', 'Game_developer',
#        'Game_distribution', 'Game_genre', 'Critic_score_0_100',
#        'Critic_num_reviews', 'User_score_0_10', 'User_num_reviews', 'Link'],
#       dtype='object')

# %%
df_vg.head(5)
# Out:
#                               Game_name  Game_platform Game_release_date  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo 64        23/11/1998
# 1                           SoulCalibur      Dreamcast        08/09/1999
# 2                   Grand Theft Auto IV  PlayStation 3        29/04/2008
# 3                    Super Mario Galaxy            Wii        12/11/2007
# 4                  Super Mario Galaxy 2            Wii        23/05/2010
#
#        Game_developer Game_distribution         Game_genre  \
# 0            Nintendo          Nintendo  Open-World Action
# 1               Namco             Namco        3D Fighting
# 2      Rockstar North    Rockstar Games  Open-World Action
# 3            Nintendo          Nintendo      3D Platformer
# 4  Nintendo EAD Tokyo          Nintendo      3D Platformer
#
#    Critic_score_0_100  Critic_num_reviews  User_score_0_10  User_num_reviews  \
# 0                99.0                22.0              9.1            8947.0
# ...

# %%
df_vg.sample(10)
# Out:
#                                                Game_name     Game_platform  \
# 5953                                       Mothergunship     PlayStation 4
# 1312   Hearthstone: Heroes of Warcraft - Goblins Vs. ...                PC
# 12371  Disney's Magical Quest 3 Starring Mickey & Donald  Game Boy Advance
# 4287                            Ghostrunner: Project_Hel                PC
# 1284                                         Viva Pinata                PC
# 12007                            Symphony of the Machine                PC
# 11714                                  Pixel Ripped 1978     PlayStation 5
# 1272                          Lonely Mountains: Downhill                PC
# 7447                          Major League Baseball 2K12                PC
# 8456                                   Warriors Orochi 3     PlayStation 3
#
#       Game_release_date                     Game_developer  \
# 5953         17/07/2018                       Grip Digital
# ...

# %%
df_vg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13012 entries, 0 to 13011
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Game_name           13012 non-null  object
#  1   Game_platform       13012 non-null  object
#  2   Game_release_date   12979 non-null  object
#  3   Game_developer      13001 non-null  object
#  4   Game_distribution   13001 non-null  object
#  5   Game_genre          13012 non-null  object
#  6   Critic_score_0_100  13007 non-null  float64
#  7   Critic_num_reviews  13006 non-null  float64
#  8   User_score_0_10     11399 non-null  float64
#  9   User_num_reviews    10975 non-null  float64
#  10  Link                13012 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.1+ MB

# %%
df_vg.dtypes
# Out:
# Game_name              object
# Game_platform          object
# Game_release_date      object
# Game_developer         object
# Game_distribution      object
# Game_genre             object
# Critic_score_0_100    float64
# Critic_num_reviews    float64
# User_score_0_10       float64
# User_num_reviews      float64
# Link                   object
# dtype: object

# %%
df_vg.describe()
# Out:
#        Critic_score_0_100  Critic_num_reviews  User_score_0_10  \
# count        13007.000000        13006.000000     11399.000000
# mean            70.236819           26.370444         7.064207
# std             12.430571           20.519597         3.377892
# min              8.300000            5.000000         0.300000
# 25%             63.000000           11.000000         6.200000
# 50%             72.000000           19.000000         7.200000
# 75%             79.000000           35.000000         7.900000
# max             99.000000          156.000000        89.000000
#
#        User_num_reviews
# count      10975.000000
# mean         256.880182
# std         1885.421761
# min            5.000000
# 25%           14.000000
# 50%           36.000000
# 75%          117.000000
# max       163766.000000

# %%
df_vg["Game_platform"].value_counts()
# Out:
# Game_platform
# PC                   4546
# PlayStation 4         981
# PlayStation 2         959
# Xbox 360              844
# PlayStation 3         759
# Nintendo Switch       728
# DS                    566
# Wii                   432
# Xbox One              409
# Game Boy Advance      364
# PSP                   353
# Xbox                  336
# 3DS                   336
# iOS (iPhone/iPad)     243
# PlayStation Vita      226
# PlayStation 5         192
# GameCube              188
# PlayStation           187
# Dreamcast             106
# Wii U                  94
# Xbox Series X          93
# Nintendo 64            65
# Meta Quest              5
# Name: count, dtype: int64

# %%
df_vg["Game_developer"].value_counts()
# Out:
# Game_developer
# Capcom              173
# Nintendo            150
# Telltale Games      115
# Konami              103
# Square Enix          77
#                    ...
# Geeta Games           1
# Pixel Perfex          1
# Mana Games            1
# Lion Shield, LLC      1
# Magic Lantern         1
# Name: count, Length: 4110, dtype: int64

# %%
df_vg["Game_distribution"].value_counts()
# Out:
# Game_distribution
# Nintendo                  613
# Ubisoft                   441
# SCEA                      403
# Sega                      397
# Electronic Arts           359
#                          ...
# Digital Cybercherries       1
# Scavengers Studio           1
# Rat King Entertainment      1
# Glumberland                 1
# Version2Games Limited       1
# Name: count, Length: 1952, dtype: int64

# %%
df_vg["Game_genre"].value_counts()
# Out:
# Game_genre
# Action Adventure      718
# 2D Platformer         663
# Action RPG            619
# FPS                   568
# Real-Time Strategy    380
#                      ...
# Train Sim               6
# Team Sports             5
# Cricket                 4
# Marine Sim              4
# Racing Sim              1
# Name: count, Length: 119, dtype: int64

# %%
df_vg["Game_release_date"].value_counts()
# Out:
# Game_release_date
# 14/11/2006    28
# 18/11/2012    22
# 20/03/2007    21
# 18/11/2003    21
# 23/10/2007    21
#               ..
# 30/04/1998     1
# 21/03/2019     1
# 29/10/2008     1
# 11/11/2012     1
# 08/05/2024     1
# Name: count, Length: 4592, dtype: int64

# %%
total_reviews_critic_distribution = df_vg.groupby("Game_distribution")["Critic_num_reviews"].sum().reset_index()
total_reviews_critic_distribution["reviews_distribution"] = total_reviews_critic_distribution["Critic_num_reviews"].astype(int)
total_reviews_critic_distribution = total_reviews_critic_distribution.drop(columns=["Critic_num_reviews"])
total_reviews_critic_distribution = total_reviews_critic_distribution.sort_values(by="reviews_distribution", ascending=False)

# %%
total_reviews_critic_distribution
# Out:
#            Game_distribution  reviews_distribution
# 1139                Nintendo                 27752
# 1418                    SCEA                 15957
# 1750                 Ubisoft                 13756
# 1461                    Sega                 13405
# 1037  Microsoft Game Studios                 12407
# ...                      ...                   ...
# 1561         Star Maid Games                     7
# 800            Honeyslug Ltd                     7
# 1761    Universal Happymaker                     7
# 762                  Hamster                     7
# 976               Ludomotion                     7
#
# [1952 rows x 2 columns]

# %%
total_reviews_user_distribution = df_vg.groupby("Game_distribution")["User_num_reviews"].sum().reset_index()
total_reviews_user_distribution["reviews_distribution"] = total_reviews_user_distribution["User_num_reviews"].astype(int)
total_reviews_user_distribution = total_reviews_user_distribution.drop(columns=["User_num_reviews"])
total_reviews_user_distribution = total_reviews_user_distribution.sort_values(by="reviews_distribution", ascending=False)

# %%
total_reviews_user_distribution
# Out:
#                    Game_distribution  reviews_distribution
# 1528  Sony Interactive Entertainment                346104
# 1139                        Nintendo                271308
# 1418                            SCEA                166006
# 533                  Electronic Arts                140505
# 1557                     Square Enix                116173
# ...                              ...                   ...
# 339                Clock Drive Games                     0
# 338                   Climax Studios                     0
# 979                        M07 Games                     0
# 1795                    Virtual Toys                     0
# 976                       Ludomotion                     0
#
# [1952 rows x 2 columns]

# %%
critic_user_reviews_genre = df_vg[0:10].groupby('Game_genre').agg({'Critic_score_0_100': 'mean', 'Critic_num_reviews': 'sum', 'User_score_0_10': 'mean', 'User_num_reviews': 'sum'})

# Plot
plt.figure(figsize=(10, 6))
critic_user_reviews_genre[['Critic_score_0_100', 'User_score_0_10']].plot(kind='bar', color=['blue', 'green'])
plt.title('Average Critic and User Scores by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Score')
plt.xticks(rotation=45)
plt.legend(['Critic Score', 'User Score'])
plt.tight_layout()

# %%
genre_distribution = df_vg['Game_genre'].value_counts()

# Plot
plt.figure(figsize=(30, 15))
genre_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Game Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
games_by_developer = df_vg['Game_developer'].value_counts()
games_by_publisher = df_vg['Game_distribution'].value_counts()

# %%
plt.figure(figsize=(10, 6))
games_by_developer.head(10).plot(kind='bar', color='orange')
plt.title('Top 10 Developers by Number of Games Published')
plt.xlabel('Developer')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
games_by_publisher.head(10).plot(kind='bar', color='purple')
plt.title('Top 10 Publishers by Number of Games Published')
plt.xlabel('Publisher')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
platform_distribution = df_vg['Game_platform'].value_counts()

# Plot
plt.figure(figsize=(12, 6))
platform_distribution.plot(kind='bar', color='lightgreen', width=0.8)  # Imposta la larghezza delle colonne
plt.title('Distribution of Games Across Platforms')
plt.xlabel('Platform')
plt.ylabel('Number of Games')
plt.xticks(rotation=45, ha='right')  # Orienta le etichette sull'asse x e allinea a destra
plt.tight_layout()

# %%
reviews_by_platform = df_vg.groupby('Game_platform').agg({'Critic_score_0_100': 'mean', 'User_score_0_10': 'mean', 'Critic_num_reviews': 'sum', 'User_num_reviews': 'sum'})

# Plot
plt.figure(figsize=(12, 6))
reviews_by_platform[['Critic_score_0_100', 'User_score_0_10']].plot(kind='bar', color=['blue', 'green'], width=0.8)  # Imposta la larghezza delle colonne
plt.title('Average Critic and User Scores by Platform')
plt.xlabel('Platform')
plt.ylabel('Average Score')
plt.xticks(rotation=45, ha='right')  # Orienta le etichette sull'asse x e allinea a destra
plt.legend(['Critic Score', 'User Score'])
plt.tight_layout()
plt.show()

# %%
reviews_by_platform = df_vg.groupby('Game_platform').agg({'Critic_num_reviews': 'sum', 'User_num_reviews': 'sum'})

# Plot
plt.figure(figsize=(20, 6))
reviews_by_platform.plot(kind='bar', stacked=True)
plt.title('Number of Reviews by Platform')
plt.xlabel('Platform')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
reviews_by_genre = df_vg.groupby('Game_genre').agg({'Critic_num_reviews': 'sum', 'User_num_reviews': 'sum'})

# Ordina il DataFrame in base al numero totale di recensioni
reviews_by_genre = reviews_by_genre.sum(axis=1).sort_values(ascending=False)

# Plot
plt.subplots(figsize=(10, 25))
ax = sns.barplot(x=reviews_by_genre, y=reviews_by_genre.index, palette='cubehelix')
ax.set_title('Number of Reviews by Genre', color='red', alpha=0.5, size=25)
ax.set_xlabel('Total Reviews', color='green', alpha=0.5, size=30)
ax.set_ylabel('Genre', color='green', alpha=0.5, size=30)
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_12144\3955081735.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=reviews_by_genre, y=reviews_by_genre.index, palette='cubehelix')
# Text(0, 0.5, 'Genre')

# %%
df_vg['Release_Year'] = pd.to_datetime(df_vg['Game_release_date']).dt.year

# Raggruppa per anno di uscita e calcola il numero totale di recensioni
reviews_by_year = df_vg.groupby('Release_Year').agg({'Critic_num_reviews': 'sum', 'User_num_reviews': 'sum'})

# Plot
plt.figure(figsize=(12, 6))
plt.scatter(reviews_by_year.index, reviews_by_year.sum(axis=1), color='blue')
plt.title('Number of Reviews by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Total Reviews')
plt.grid(True)
plt.tight_layout()
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_12144\1570505779.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_vg['Release_Year'] = pd.to_datetime(df_vg['Game_release_date']).dt.year

# %%
reviews_2020 = df_vg[df_vg['Release_Year'] == 2020][['Game_name', 'Critic_num_reviews', 'User_num_reviews']]

reviews_2020[['Critic_num_reviews', 'User_num_reviews']] = reviews_2020[['Critic_num_reviews', 'User_num_reviews']].fillna(pd.NA).astype('Int64')

reviews_2020 = reviews_2020.sort_values(by=['User_num_reviews', 'Critic_num_reviews'], ascending=False)

reviews_2020
# Out:
#                         Game_name  Critic_num_reviews  User_num_reviews
# 84         The Last of Us Part II                 132            163766
# 986                Cyberpunk 2077                 106             35494
# 9354       Warcraft III: Reforged                  53             31161
# 1551            Ghost of Tsushima                 132             21974
# 643      Final Fantasy VII Remake                 135              8532
# ...                           ...                 ...               ...
# 12550                     GERRRMS                   7              <NA>
# 12570             Old Gods Rising                   7              <NA>
# 12571           Road to Guangdong                   7              <NA>
# 12654  Strobophagia | Rave Horror                   7              <NA>
# 12720                    Picklock                   7              <NA>
#
# [600 rows x 3 columns]

# %%
total_reviews_2020 = int(reviews_2020[['Critic_num_reviews', 'User_num_reviews']].sum().sum())
total_reviews_2020
# Out:
# 397402

# %%
df_vg['Total_reviews'] = df_vg[['Critic_num_reviews', 'User_num_reviews']].sum(axis=1)

# Converti le colonne delle recensioni dei critici, degli utenti e delle recensioni totali in interi
df_vg[['Critic_num_reviews', 'User_num_reviews', 'Total_reviews']] = df_vg[['Critic_num_reviews', 'User_num_reviews', 'Total_reviews']].fillna(0).astype(int)

# Seleziona i top 10 giochi con il numero più alto di recensioni
top_10_games = df_vg.nlargest(10, 'Total_reviews')[['Game_name', 'Game_release_date', 'Critic_num_reviews', 'Critic_score_0_100', 'User_num_reviews', 'User_score_0_10', 'Total_reviews']]

# Visualizza i top 10 giochi con numeri interi
top_10_games
# Out:
#                                     Game_name Game_release_date  \
# 84                     The Last of Us Part II        19/06/2020
# 986                            Cyberpunk 2077        10/12/2020
# 9354                   Warcraft III: Reforged        28/01/2020
# 110                                God of War        20/04/2018
# 7                       Red Dead Redemption 2        26/10/2018
# 5     The Legend of Zelda: Breath of the Wild        03/03/2017
# 1551                        Ghost of Tsushima        17/07/2020
# 46                  The Last of Us Remastered        29/07/2014
# 152                  The Witcher 3: Wild Hunt        19/05/2015
# 2011                          Death Stranding        08/11/2019
#
#       Critic_num_reviews  Critic_score_0_100  User_num_reviews  \
# 84                   132                93.0            163766
# 986                  106                86.0             35494
# 9354                  53                59.0             31161
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_vg['Critic_score_0_100'].dropna(), bins=20, color='blue', alpha=0.7)
plt.xlabel('Critic Score (0-100)')
plt.ylabel('Frequency')
plt.title('Distribution of Critic Review Scores')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_vg['User_score_0_10'].dropna(), bins=range(11), color='green', alpha=0.7)
plt.xlabel('User Score (0-10)')
plt.ylabel('Frequency')
plt.title('Distribution of User Review Scores')
plt.grid(True)
plt.show()

# %%
df_vg['Game_release_date'] = pd.to_datetime(df_vg['Game_release_date'])

# Extract year from 'Game_release_date'
df_vg['Year'] = df_vg['Game_release_date'].dt.year

# Group by year and calculate average critic and user scores
avg_scores = df_vg.groupby('Year').agg({'Critic_score_0_100': 'mean', 'User_score_0_10': lambda x: x.mean() * 10})

# Plot the average scores over the years
plt.figure(figsize=(10, 6))
plt.plot(avg_scores.index, avg_scores['Critic_score_0_100'], marker='o', color='blue', label='Average Critic Score')
plt.plot(avg_scores.index, avg_scores['User_score_0_10'], marker='o', color='green', label='Average User Score (scaled)')
plt.xlabel('Year')
plt.ylabel('Average Score')
plt.title('Average Critic and User Scores Over the Years')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_12144\2533060218.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_vg['Game_release_date'] = pd.to_datetime(df_vg['Game_release_date'])

# %%
reviews_2024 = df_vg[df_vg['Release_Year'] == 2024][['Game_name', 'Critic_num_reviews', 'User_num_reviews', 'Critic_score_0_100', 'User_score_0_10']]

reviews_2024[['Critic_num_reviews', 'User_num_reviews']] = reviews_2024[['Critic_num_reviews', 'User_num_reviews']].fillna(pd.NA).astype('Int64')

reviews_2024 = reviews_2024.sort_values(by=['User_num_reviews', 'Critic_num_reviews', 'Critic_score_0_100', 'User_score_0_10'], ascending=False)

reviews_2024
# Out:
#                                     Game_name  Critic_num_reviews  \
# 128                 Final Fantasy VII Rebirth                 141
# 9289   Suicide Squad: Kill The Justice League                  90
# 2010                             Helldivers 2                  66
# 315         The Last of Us Part II Remastered                  91
# 1474                            Anomaly Agent                  11
# ...                                       ...                 ...
# 11237                           BORE BLASTERS                   8
# 11274              The Legend of Steel Empire                   8
# 10974                                   qomp2                   7
# 11419                    Top Racer Collection                   7
# 12038                Chronique des Silencieux                   7
#
#        User_num_reviews  Critic_score_0_100  User_score_0_10
# 128                2570                92.0              9.0
# ...

# %%
df_copy = df_vg

# %%
df_copy['Critic_score_0_100'] = df_copy['Critic_score_0_100'].fillna(np.nan)
df_copy['User_score_0_10'] = df_copy['User_score_0_10'].fillna(np.nan)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_copy['Critic_num_reviews'], df_copy['Critic_score_0_100'], alpha=0.5)
plt.xlabel('Critic Number of Reviews')
plt.ylabel('Critic Score')
plt.title('Relationship between Total Critic Reviews and Critic Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_copy['User_num_reviews'], df_copy['User_score_0_10'], alpha=0.5)
plt.xlabel('User_num_reviews')
plt.ylabel('User Score')
plt.title('Relationship between Total User Reviews and User Score')
plt.grid(True)
plt.show()

# %%
games_with_invalid_user_scores = df_copy[df_copy['User_score_0_10'] > 10]

# Visualizza i giochi con punteggio degli utenti superiore a 10
print("Giochi con punteggio degli utenti superiore a 10:")
print(games_with_invalid_user_scores[['Game_name', 'User_score_0_10']])
# Out:
# Giochi con punteggio degli utenti superiore a 10:
#                                          Game_name  User_score_0_10
# 10968                                    Soul Edge             89.0
# 10970  Age of Empires II: The Conquerors Expansion             88.0
# 10973                          Ultimate Card Games             87.0
# 11008                          Myst IV: Revelation             82.0
# 11054                                  MultiVersus             80.0
# 11057           The King of Fighters EX: Neo Blood             80.0
# 11091                                     RayStorm             79.0
# 11216                            American Conquest             76.0
# 11262                  Battlefield 2: Armored Fury             75.0
# 11288                              A Vampyre Story             75.0
# 11292                            X-Plane Version 7             75.0
# 11317               Ankh: Curse of the Scarab King             74.0
# ...

# %%
games_with_invalid_user_scores = df_copy[df_copy['User_score_0_10'] > 10]

# Calcola il numero di giochi con punteggio degli utenti superiore a 10
num_games_with_invalid_scores = games_with_invalid_user_scores.shape[0]

# Stampa il numero di giochi con punteggio degli utenti superiore a 10
print("Numero di giochi con punteggio degli utenti superiore a 10:", num_games_with_invalid_scores)
# Out:
# Numero di giochi con punteggio degli utenti superiore a 10: 29

# %%
# Seleziona le righe con user_score_0_10 superiore a 10 e imposta i valori a NaN
df_copy.loc[df_copy['User_score_0_10'] > 10, 'User_score_0_10'] = np.nan

# %%
games_with_invalid_user_scores = df_copy[df_copy['User_score_0_10'] > 10]

# Calcola il numero di giochi con punteggio degli utenti superiore a 10
num_games_with_invalid_scores = games_with_invalid_user_scores.shape[0]

# Stampa il numero di giochi con punteggio degli utenti superiore a 10
print("Numero di giochi con punteggio degli utenti superiore a 10:", num_games_with_invalid_scores)
# Out:
# Numero di giochi con punteggio degli utenti superiore a 10: 0

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_copy['Total_reviews'], df_copy['Critic_score_0_100'], label='Critic Score', alpha=0.5)
plt.scatter(df_copy['Total_reviews'], df_copy['User_score_0_10'] * 10, label='User Score', alpha=0.5)
plt.xlabel('Total Reviews')
plt.ylabel('Score')
plt.title('Relationship between Total Reviews and Scores')
plt.legend()
plt.grid(True)
plt.show()

# %%
top_10_games_critic_reviews = df_copy.nlargest(10, 'Critic_num_reviews')
selected_columns = ['Game_name', 'Game_platform', 'Game_release_date', 'Game_genre', 'Critic_num_reviews', 'User_num_reviews']
top_10_games_critic_reviews[selected_columns]
# Out:
#                                       Game_name    Game_platform  \
# 27    The Legend of Zelda: Tears of the Kingdom  Nintendo Switch
# 70                         God of War: Ragnarok    PlayStation 5
# 288                       Marvel's Spider-Man 2    PlayStation 5
# 671                           Final Fantasy XVI    PlayStation 5
# 1205               Kirby and the Forgotten Land  Nintendo Switch
# 128                   Final Fantasy VII Rebirth    PlayStation 5
# 552                      Horizon Forbidden West    PlayStation 5
# 532                 Ratchet & Clank: Rift Apart    PlayStation 5
# 137                    Super Mario Bros. Wonder  Nintendo Switch
# 643                    Final Fantasy VII Remake    PlayStation 4
#
#      Game_release_date         Game_genre  Critic_num_reviews  \
# 27          2023-05-12  Open-World Action                 156
# 70          2022-11-09   Action Adventure                 150
# ...

# %%
df_vg['Average_score'] = (df_vg['Critic_score_0_100'] + df_vg['User_score_0_10'] * 10) / 2

# Ordina il DataFrame in base all'average score in ordine decrescente
top_10_games = df_vg.sort_values(by='Average_score', ascending=False).head(10)

# Visualizza i top 10 giochi con punteggio medio più alto
top_10_games[['Game_name', 'Average_score']]
# Out:
#                                          Game_name  Average_score
# 10968                                    Soul Edge          489.5
# 10970  Age of Empires II: The Conquerors Expansion          484.0
# 10973                          Ultimate Card Games          478.5
# 11008                          Myst IV: Revelation          451.0
# 11054                                  MultiVersus          440.0
# 11057           The King of Fighters EX: Neo Blood          440.0
# 11091                                     RayStorm          434.5
# 11216                            American Conquest          418.0
# 11262                  Battlefield 2: Armored Fury          412.5
# 11288                              A Vampyre Story          412.5

# %%
soul_edge_data = df_vg[df_vg['Game_name'] == "Soul Edge"]

# Visualizza i dati del gioco "Soul Edge"
soul_edge_data
# Out:
#        Game_name Game_platform Game_release_date Game_developer  \
# 10968  Soul Edge   PlayStation               NaT          Namco
#
#       Game_distribution   Game_genre  Critic_score_0_100  Critic_num_reviews  \
# 10968             Namco  3D Fighting                89.0                  12
#
#        User_score_0_10  User_num_reviews              Link  Total_reviews  \
# 10968             89.0                 0  /game/soul-edge/             12
#
#        Release_Year  Year  Average_score
# 10968           NaN   NaN          489.5
